# %%
                                                             #Python Day-2

# %%
#Code in single cell

# %%
firstname= 'Sindhu'
print(firstname)
# Out:
# Sindhu

# %%
#In different cells

# %%
firstname = 'Sindhu'

# %%
print(firstname)
# Out:
# Sindhu

# %%
a='2'
b='3'
c="a+b"
print (c)
# Out:
# a+b

# %%
#If you add quotes then it will be considered as a strings and it will combine them istead of adding

# %%
a='2'
b='3'
c= a+b
print (c)
# Out:
# 23

# %%
#for adding numbers you should not use quotes("2"/'2')

# %%
a=2
b= 3
c= a + b
print (c)
# Out:
# 5

# %%
                                                       #Variable Declaration

# %%
#Rule-1
#If a variable has space in between them then it leads to error

# %%
first name = 'Sindhu'
print (first name)
# Out:
#   Cell In[117], line 1
#     first name = 'Sindhu'
#           ^
# SyntaxError: invalid syntax

# %%
#as there is space between the first and name it leaded to the error

# %%
firstname = 'Sindhu'
print (firstname)
# Out:
# Sindhu

# %%
#So there should be no space in between the variable

# %%
#Rule-2
A variable should not start with a number

# %%
1name = 'Sindhu'
print(1name)
# Out:
#   Cell In[115], line 1
#     1name = 'Sindhu'
#     ^
# SyntaxError: invalid decimal literal

# %%
#As the variable started with a number, error poped

# %%
name1 = 'Sindhu'
print(name1)
# Out:
# Sindhu

# %%
#A variable can end with a number

# %%
name1first = 'Sindhu'
print(name1first)
# Out:
# Sindhu

# %%
#A variable can also contain a number in between

# %%
First1Name= 'Sindhu'
print(First1Name)
# Out:
# Sindhu

# %%
#Rule-3
A varible should not contain any special characters(@,#,%,$,&,*)

# %%
name@ = 'Sindhu'
print(name@)
# Out:
#   Cell In[110], line 1
#     name@ = 'Sindhu'
#           ^
# SyntaxError: invalid syntax

# %%
# Due to special character '@' we got the error

# %%
                                                #Data types***

# %%
#We have 5 data types in the Python programming language

# %% [raw]
# Strings---> str

# %%
Numbers--->  integers--->int& float (decimal)--> 0.1,0.2

# %%
List---> list

# %%
Tuples---> tuple

# %%
Dictionaries---> dict

# %%
***Python is a case sensitive programming language***

# %%
#Classification of Data types

# %%
there are two types, they are

# %%
1- Mutable---- able to edit
2- Immutable---- not able to edit

# %%
#Intro to String datatype

# %%
>A string is nothing but a series of characters declared in a quotes.

# %%
>It is classified into #immutable data type

# %%
> String should be defined in single or double qoutes

# %%
#ex:

# %%
name= 'Sindhu'
print(name)
# Out:
# Sindhu

# %%
#Sindhu is the string here

# %%
#Intro to string methods

# %%
#type method - determines the type of data

# %%
type(name)
# Out:
# str

# %%
type(2)
# Out:
# int

# %%
#title method--- changes name 1st letters to captial lettters

# %%
fullname= 'sindhu komati'

# %%
print(fullname.title())
# Out:
# Sindhu Komati

# %%
#upper method---upper case letters

# %%
print(fullname.upper())
# Out:
# SINDHU KOMATI

# %%
#lower method---lower case or small letters

# %%
print(fullname.lower())
# Out:
# sindhu komati
