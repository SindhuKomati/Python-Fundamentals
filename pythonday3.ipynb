# %%
                                                 # Day - 3

# %%
#Introduction to 'f' strings

# %%
#Syntax

# %%
#f'custom_message,{place_holder-1}{place_holder2}----{place_holdern}"

# %%
firstname= "Sindhu"

# %%
lastname= " komati"

# %%
#req: I want to get the full name..

# %%
fullname= f"{firstname}{lastname}"

# %%
print(fullname)
# Out:
# Sindhu komati

# %%
print(fullname.title())
# Out:
# Sindhu Komati

# %%
message= f"Keep up the good work,{fullname.title()}"

# %%
print(message)
# Out:
# Keep up the good work,Sindhu Komati

# %%
#Adding white spaces to the strings

# %%
               # \n for next line and \t for tab space and next line

# %%
print("fvrt_prog_lang:pythonc++javac")
# Out:
# fvrt_prog_lang:pythonc++javac

# %%
#by using \n

# %%
print("fvrt_prog_lang:\npython\nc++\njava\nc")
# Out:
# fvrt_prog_lang:
# python
# c++
# java
# c

# %%
#by using \t

# %%
print("fvrt_prog_lang:\n\tpython\n\tc++\n\tjava\n\tc")
# Out:
# fvrt_prog_lang:
# 	python
# 	c++
# 	java
# 	c

# %%
#Removing white spaces from the strings

# %%
name= " sindhu"

# %%
print(name)
# Out:
#  sindhu

# %%
#by using the lstrip() method we can remove the left side white space

# %%
name.lstrip()
# Out:
# 'sindhu'

# %%
#by using the rstrip() method we can remove the right side white space

# %%
name1= "sindhu  "

# %%
print(name1)
# Out:
# sindhu

# %%
name1.rstrip()
# Out:
# 'sindhu'

# %%
name2 = "  Sindhu  "

# %%
print(name2)
# Out:
#   Sindhu

# %%
name2.strip()
# Out:
# 'Sindhu'
